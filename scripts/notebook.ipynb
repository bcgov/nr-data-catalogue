# %%
from config import *

def get_most_recent_csv(directory):
    """
    Fetch the most recent CSV file from the specified directory.
    :param directory: Path to the directory containing CSV files.
    :return: Path to the most recent CSV file, or None if no files are found.
    """
    # Get all CSV files in the directory
    csv_files = glob.glob(os.path.join(directory, "*.csv"))
    if not csv_files:
        print("No CSV files found in the directory.")
        return None

    # Find the most recent file based on modification time
    most_recent_file = max(csv_files, key=os.path.getmtime)
    print(f"Most recent CSV file: {most_recent_file}")
    return most_recent_file


def main():
    # Specify the directory where CSVs are stored
    tests_folder = "tests"

    # Get the most recent CSV file
    recent_csv = get_most_recent_csv(tests_folder)
    if recent_csv:
        print(f"Processing file: {recent_csv}")

        # Read the CSV into a DataFrame
        try:
            df = pd.read_csv(recent_csv)
            print(f"Loaded CSV with {len(df)} rows and {len(df.columns)} columns.")
            return df
        except Exception as e:
            print(f"An error occurred while reading the CSV: {e}")

if __name__ == "__main__":
    df = main()
# Out:
# Most recent CSV file: tests\test_tables_with_columns_20241210_151819.csv
# Processing file: tests\test_tables_with_columns_20241210_151819.csv
# Loaded CSV with 135702 rows and 5 columns.
#                                     Table ID  \
# 0       aff703b7-c7a4-4f04-a85d-b741e6f97fea
# 1       aff703b7-c7a4-4f04-a85d-b741e6f97fea
# 2       aff703b7-c7a4-4f04-a85d-b741e6f97fea
# 3       aff703b7-c7a4-4f04-a85d-b741e6f97fea
# 4       aff703b7-c7a4-4f04-a85d-b741e6f97fea
# ...                                      ...
# 135697  84be4e30-345b-42c4-871a-b4ca8b9f9905
# 135698  84be4e30-345b-42c4-871a-b4ca8b9f9905
# 135699  7850dac7-8dfc-4d7d-a13c-0005db93eb71
# 135700  7850dac7-8dfc-4d7d-a13c-0005db93eb71
# 135701  7850dac7-8dfc-4d7d-a13c-0005db93eb71
#
#                                                Table Name  \
# 0              DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE
# 1              DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE
# 2              DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE
# 3              DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE
# 4              DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE
# ...                                                   ...
# 135697                GEOBC Test Database.GEOTST.aps.ZONE
# 135698                GEOBC Test Database.GEOTST.aps.ZONE
# 135699  ENV Test Database.ENVTEST1.fiss.ZZ_FISS_REFERE...
# 135700  ENV Test Database.ENVTEST1.fiss.ZZ_FISS_REFERE...
# 135701  ENV Test Database.ENVTEST1.fiss.ZZ_FISS_REFERE...
#
#                     Table Tags                 Column Name  \
# 0       Application System.FTA  aac_adjustment_reason_code
# 1       Application System.FTA                 description
# 2       Application System.FTA              effective_date
# 3       Application System.FTA                 expiry_date
# 4       Application System.FTA            update_timestamp
# ...                        ...                         ...
# 135697                     NaN                zone_zone_no
# 135698                     NaN     zone_contract_qualifier
# 135699                     NaN                   fgrthm_id
# 135700                     NaN                         seq
# 135701                     NaN                    comments
#
#                                 Column Tags
# 0       Data Security Classification.Public
# 1       Data Security Classification.Public
# 2       Data Security Classification.Public
# 3       Data Security Classification.Public
# 4       Data Security Classification.Public
# ...                                     ...
# 135697                                  NaN
# 135698                                  NaN
# 135699                                  NaN
# 135700                                  NaN
# 135701                                  NaN
#
# [135702 rows x 5 columns]

# %%
df['Column Tags'].unique()
# Out:
# array(['Data Security Classification.Public', nan,
#        'Data Security Classification.Protected A',
#        'Data Security Classification.Protected B'], dtype=object)
