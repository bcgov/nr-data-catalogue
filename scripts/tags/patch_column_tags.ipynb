# %% [markdown]
# # Patching Columns based on values provided on given CSV

# %% [markdown]
# CSV Assumptions:
#
# 1. The email's CSV has the correct number of columns and does not leave anything out.
#
#     ie If a table has 10 columns, all those columns are accounted for in the CSV and there is 0 instances of missing columns (ie 9/10 columns instead of 10/10 columns)
#
#     The number of columns is critical to this exercise and it must be accurate.
#
#
#
# 2. The DBQ01 tables represented in this exercise can be interchanged with DBP01 tables like for like.
#
# Reference: DAP-419
# https://apps.nrs.gov.bc.ca/int/jira/browse/DAP-419

# %%
import os
os.chdir("..")
from config import *
# Out:
# Environment: test
# Base URL: https://nr-data-catalogue-test.apps.emerald.devops.gov.bc.ca/api/v1

# %% [markdown]
# Ok great, let's try a PATCH request to ADD a tag based on column index

# %%
# Table and column identifiers
table_id = "aff703b7-c7a4-4f04-a85d-b741e6f97fea"
column_index = 0  # As found from your previous query

# URL for the PATCH request
url = f"https://nr-data-catalogue-test.apps.emerald.devops.gov.bc.ca/api/v1/tables/{table_id}?fields=columns,tags"

# JSON body for adding a tag to the specific column
data = [
    {
        "op": "add",  # "add" since you want to append the new tag
        "path": f"/columns/4/tags",  # Use the column index
        "value": [
            {
                "tagFQN": "Data Security Classification.Public" , # Fully Qualified Name of the tag
                 "labelType": "Manual",  # Label type
                 "state": "Confirmed"  # Tag state
            }
        ]
    }
]


# Send the PATCH request to add the tag
response = requests.patch(url, headers=headers_patch, json=data)

# Output the response status and message
if response.status_code == 200:
    print("Tag added successfully!")
else:
    print(f"Failed to add tag: {response.status_code}")
    print(response.json())
# Out:
# Tag added successfully!

# %% [markdown]
# Now, let's remove that tag

# %%
# JSON body for adding a tag to the specific column
data = [
    {
        "op": "remove",  # "add" since you want to append the new tag
        "path": f"/columns/4/tags",  # Use the column index
        "value": [
            {
                "tagFQN": "Data Security Classification.Public" , # Fully Qualified Name of the tag
                 "labelType": "Manual",  # Label type
                 "state": "Confirmed"  # Tag state
            }
        ]
    }
]


# Send the PATCH request to add the tag
response = requests.patch(url, headers=headers_patch, json=data)

# Output the response status and message
if response.status_code == 200:
    print("Tag removed successfully!")
else:
    print(f"Failed to remove tag: {response.status_code}")
    print(response.json())
# Out:
# Tag removed successfully!

# %% [markdown]
# Previously, we added a tag based on table ID, let's try based on table FQN

# %%
# Table and column identifiers
table_fqn = "DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE"
column_index = 0  # As found from your previous query

# URL for the PATCH request
url_fqn = f"https://nr-data-catalogue-test.apps.emerald.devops.gov.bc.ca/api/v1/tables/name/{table_fqn}?fields=columns,tags"

# JSON body for adding a tag to the specific column
data = [
    {
        "op": "add",  # "add" since you want to append the new tag
        "path": f"/columns/3/tags",  # Use the column index
        "value": [
            {
                "tagFQN": "Data Security Classification.Public" , # Fully Qualified Name of the tag
                 "labelType": "Manual",  # Label type
                 "state": "Confirmed"  # Tag state
            }
        ]
    }
]

# Send the PATCH request to add the tag
response = requests.patch(url_fqn, headers=headers_patch, json=data)

# Output the response status and message
if response.status_code == 200:
    print("Tag added successfully!")
else:
    print(f"Failed to add tag: {response.status_code}")
    print(response.json())
# Out:
# Tag added successfully!

# %% [markdown]
# Ok great, let's try to add tags based on the information provided on a CSV.
# The information on the CSV is strategically formatted in a way that should make things easy for us.

# %%
# df = pd.read_csv('reference_csvs/all_cols.csv').drop('Unnamed: 0',axis=1)
df = get_most_recent_csv('tests')
# Out:
# Most recent CSV file: tests\test_tables_with_columns_20241213_085805.csv
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 # df = pd.read_csv('reference_csvs/all_cols.csv').drop('Unnamed: 0',axis=1)
#       2 df = get_most_recent_csv('tests')
# ----> 3 df.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %% [markdown]
# The CSV we just imported contains all the tables and columns available in the DEV instance of our OpenMetaData Data Catalog (100,000+ rows).
#
# It contains a near empty 'Tags' column which we need to fill using the information provided from another CSV (a compilation of the email's CSVs)...

# %%
# Let's give column indexes to the values on the spreadsheet, this will be important later on
df['index'] = df.groupby('Table Name').cumcount()
df.head(30)
# Out:
#                                            Table Name     env   Database  \
# 0          DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE   DBQ01      DBQ01
# 1          DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE   DBQ01      DBQ01
# 2          DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE   DBQ01      DBQ01
# 3          DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE   DBQ01      DBQ01
# 4          DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE   DBQ01      DBQ01
# 5   dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 6   dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 7   dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 8   dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 9   dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 10  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 11  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 12  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 13  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 14  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 15  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 16  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 17  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 18  dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...  dlhdev  lhousedev
# 19              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 20              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 21              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 22              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 23              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 24              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 25              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 26              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 27              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 28              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
# 29              DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT   DBQ01      DBQ01
#
#                      Schema                       Table  \
# 0                       the  AAC_ADJUSTMENT_REASON_CODE
# 1                       the  AAC_ADJUSTMENT_REASON_CODE
# 2                       the  AAC_ADJUSTMENT_REASON_CODE
# 3                       the  AAC_ADJUSTMENT_REASON_CODE
# 4                       the  AAC_ADJUSTMENT_REASON_CODE
# 5   fdw_ods_fta_replication       aac_allocation_amount
# 6   fdw_ods_fta_replication       aac_allocation_amount
# 7   fdw_ods_fta_replication       aac_allocation_amount
# 8   fdw_ods_fta_replication       aac_allocation_amount
# 9   fdw_ods_fta_replication       aac_allocation_amount
# 10  fdw_ods_fta_replication       aac_allocation_amount
# 11  fdw_ods_fta_replication       aac_allocation_amount
# 12  fdw_ods_fta_replication       aac_allocation_amount
# 13  fdw_ods_fta_replication       aac_allocation_amount
# 14  fdw_ods_fta_replication       aac_allocation_amount
# 15  fdw_ods_fta_replication       aac_allocation_amount
# 16  fdw_ods_fta_replication       aac_allocation_amount
# 17  fdw_ods_fta_replication       aac_allocation_amount
# 18  fdw_ods_fta_replication       aac_allocation_amount
# 19                      the       AAC_ALLOCATION_AMOUNT
# 20                      the       AAC_ALLOCATION_AMOUNT
# 21                      the       AAC_ALLOCATION_AMOUNT
# 22                      the       AAC_ALLOCATION_AMOUNT
# 23                      the       AAC_ALLOCATION_AMOUNT
# 24                      the       AAC_ALLOCATION_AMOUNT
# 25                      the       AAC_ALLOCATION_AMOUNT
# 26                      the       AAC_ALLOCATION_AMOUNT
# 27                      the       AAC_ALLOCATION_AMOUNT
# 28                      the       AAC_ALLOCATION_AMOUNT
# 29                      the       AAC_ALLOCATION_AMOUNT
#
#                         Column                                  Tag  index
# 0   aac_adjustment_reason_code  Test Classification.Ignore this tag      0
# 1                  description  Test Classification.Ignore this tag      1
# 2               effective_date                                  NaN      2
# 3                  expiry_date                                  NaN      3
# 4             update_timestamp                                  NaN      4
# 5     aac_allocation_amount_id                                  NaN      0
# 6   aac_adjustment_reason_code                                  NaN      1
# 7     aac_allocation_period_id                                  NaN      2
# 8     allowable_area_type_code                                  NaN      3
# 9      allowable_cut_type_code                                  NaN      4
# 10           allocation_amount                                  NaN      5
# 11          adjustment_comment                                  NaN      6
# 12              revision_count                                  NaN      7
# 13                entry_userid                                  NaN      8
# 14             entry_timestamp                                  NaN      9
# 15               update_userid                                  NaN     10
# 16            update_timestamp                                  NaN     11
# 17    fra2003_fn_share_vol_aac                                  NaN     12
# 18        is_revenue_shareable                                  NaN     13
# 19    aac_allocation_amount_id  Data Security Classification.Public      0
# 20  aac_adjustment_reason_code  Data Security Classification.Public      1
# 21    aac_allocation_period_id  Data Security Classification.Public      2
# 22    allowable_area_type_code                                  NaN      3
# 23     allowable_cut_type_code                                  NaN      4
# 24           allocation_amount                                  NaN      5
# 25          adjustment_comment                                  NaN      6
# 26              revision_count                                  NaN      7
# 27                entry_userid                                  NaN      8
# 28             entry_timestamp                                  NaN      9
# 29               update_userid                                  NaN     10

# %% [markdown]
# The formatting for both CSV's need to be consistent to help merge them, the next few steps will take care of that

# %%
# Filter rows where the column contains alphabetic characters that are only uppercase (ignores non-alphabetic)
uppercase_only_df = df[df['Column'].apply(lambda x: any(c.isupper() for c in x) and all(not c.islower() for c in x))]

# Display the result
pd.set_option('display.max_rows', None)
uppercase_only_df
# Out:
#                                                Table Name  \
# 7616     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_G
# 7618     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_G
# 7622     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_H
# 7624     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_H
# 7632     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_I
# 7634     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_I
# 7636     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_I
# 7637     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_I
# 7647     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_L
# 7649     ENV Test Database.ENVTEST1.pscis.AQ$_PSCIS_QTB_L
# 8508    ENV Test Database.ENVTEST1.fish.ART_MACRO_REACHES
# 28133                         DBQ01.DBQ01.consep.CNS_T_JV
# 28198                    DBQ01.DBQ01.consep.CNS_T_JV_TEMP
# 34820   geobc test database.GEOTST.csa.csas_info_resul...
# 34826   geobc test database.GEOTST.csa.csas_info_resul...
# 34830   geobc test database.GEOTST.csa.csas_info_resul...
# 34837   geobc test database.GEOTST.csa.csas_info_resul...
# 34843   geobc test database.GEOTST.csa.csas_info_resul...
# 34846   geobc test database.GEOTST.csa.csas_info_resul...
# 34850   geobc test database.GEOTST.csa.csas_info_resul...
# 34853   geobc test database.GEOTST.csa.csas_info_resul...
# 34858   geobc test database.GEOTST.csa.csas_info_resul...
# 34863   geobc test database.GEOTST.csa.csas_info_resul...
# 34867   geobc test database.GEOTST.csa.csas_info_resul...
# 34872   geobc test database.GEOTST.csa.csas_info_resul...
# 34876   geobc test database.GEOTST.csa.csas_info_resul...
# 34882   geobc test database.GEOTST.csa.csas_info_resul...
# 34891   geobc test database.GEOTST.csa.csas_info_resul...
# 34896   geobc test database.GEOTST.csa.csas_info_resul...
# 51920   ENV Test Database.ENVTEST1.fish.fish_habitat_m...
# 52104   ENV Test Database.ENVTEST1.fish.fish_stream_di...
# 55255   ENV Test Database.ENVTEST1.fish.FRAB_OBSTRUCTIONS
# 63947   ENV Test Database.ENVTEST1.fish.GIS_FISS_LOCAT...
# 76515       ENV Test Database.ENVTEST1.fish.MACRO_REACHES
# 76563   ENV Test Database.ENVTEST1.fish.MACRO_REACHES_LOG
# 76566   ENV Test Database.ENVTEST1.fish.macro_reaches_...
# 118900  RRS Test Database.RRSTST1.app_rrs.VAR_WIDTH_SU...
# 120107        ENV Test Database.ENVTEST1.vgis.veg_ch_01_1
# 120108        ENV Test Database.ENVTEST1.vgis.veg_ch_01_1
# 120109        ENV Test Database.ENVTEST1.vgis.veg_ch_01_1
# 120110        ENV Test Database.ENVTEST1.vgis.veg_ch_01_1
# 120123        ENV Test Database.ENVTEST1.vgis.veg_ch_01_1
# 120147   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2000
# 120148   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2000
# 120149   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2000
# 120150   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2000
# 120163   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2000
# 120187   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2012
# 120188   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2012
# 120189   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2012
# 120190   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2012
# 120203   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2012
# 120227   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2013
# 120228   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2013
# 120229   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2013
# 120230   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2013
# 120243   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2013
# 120267   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2014
# 120268   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2014
# 120269   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2014
# 120270   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2014
# 120283   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2014
# 120307   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2015
# 120308   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2015
# 120309   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2015
# 120310   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2015
# 120323   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2015
# 120347   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2018
# 120348   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2018
# 120349   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2018
# 120350   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2018
# 120363   ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_2018
# 120387     ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_99
# 120388     ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_99
# 120389     ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_99
# 120390     ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_99
# 120403     ENV Test Database.ENVTEST1.vgis.veg_ch_01_1_99
# 120615        ENV Test Database.ENVTEST1.vgis.veg_eo_16_1
# 120616        ENV Test Database.ENVTEST1.vgis.veg_eo_16_1
# 120661        ENV Test Database.ENVTEST1.vgis.veg_ep_12_1
# 120662        ENV Test Database.ENVTEST1.vgis.veg_ep_12_1
# 120706        ENV Test Database.ENVTEST1.vgis.veg_ep_12_2
# 120753        ENV Test Database.ENVTEST1.vgis.veg_et_14_1
# 120754        ENV Test Database.ENVTEST1.vgis.veg_et_14_1
# 120855        ENV Test Database.ENVTEST1.vgis.veg_ew_06_1
# 120856        ENV Test Database.ENVTEST1.vgis.veg_ew_06_1
# 120857        ENV Test Database.ENVTEST1.vgis.veg_ew_06_1
# 120867        ENV Test Database.ENVTEST1.vgis.veg_ew_06_2
# 120886        ENV Test Database.ENVTEST1.vgis.veg_ew_06_3
# 120903        ENV Test Database.ENVTEST1.vgis.veg_ew_06_4
# 121186        ENV Test Database.ENVTEST1.vgis.veg_rs_04_1
# 121187        ENV Test Database.ENVTEST1.vgis.veg_rs_04_1
# 121188        ENV Test Database.ENVTEST1.vgis.veg_rs_04_1
# 121206        ENV Test Database.ENVTEST1.vgis.veg_rs_04_2
# 121231        ENV Test Database.ENVTEST1.vgis.veg_rs_04_3
# 121262        ENV Test Database.ENVTEST1.vgis.veg_ta_11_2
# 126302  ENV Test Database.ENVTEST1.fish.WATERBODY_COVE...
# 126310  ENV Test Database.ENVTEST1.fish.WATERBODY_COVE...
#
#                         env  Database   Schema                          Table  \
# 7616      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_G
# 7618      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_G
# 7622      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_H
# 7624      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_H
# 7632      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_I
# 7634      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_I
# 7636      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_I
# 7637      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_I
# 7647      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_L
# 7649      ENV Test Database  ENVTEST1    pscis                AQ$_PSCIS_QTB_L
# 8508      ENV Test Database  ENVTEST1     fish              ART_MACRO_REACHES
# 28133                 DBQ01     DBQ01   consep                       CNS_T_JV
# 28198                 DBQ01     DBQ01   consep                  CNS_T_JV_TEMP
# 34820   geobc test database    GEOTST      csa            csas_info_resultant
# 34826   geobc test database    GEOTST      csa            csas_info_resultant
# 34830   geobc test database    GEOTST      csa            csas_info_resultant
# 34837   geobc test database    GEOTST      csa            csas_info_resultant
# 34843   geobc test database    GEOTST      csa            csas_info_resultant
# 34846   geobc test database    GEOTST      csa            csas_info_resultant
# 34850   geobc test database    GEOTST      csa            csas_info_resultant
# 34853   geobc test database    GEOTST      csa            csas_info_resultant
# 34858   geobc test database    GEOTST      csa            csas_info_resultant
# 34863   geobc test database    GEOTST      csa            csas_info_resultant
# 34867   geobc test database    GEOTST      csa            csas_info_resultant
# 34872   geobc test database    GEOTST      csa            csas_info_resultant
# 34876   geobc test database    GEOTST      csa            csas_info_resultant
# 34882   geobc test database    GEOTST      csa            csas_info_resultant
# 34891   geobc test database    GEOTST      csa            csas_info_resultant
# 34896   geobc test database    GEOTST      csa            csas_info_resultant
# 51920     ENV Test Database  ENVTEST1     fish     fish_habitat_macro_reaches
# 52104     ENV Test Database  ENVTEST1     fish      fish_stream_distributions
# 55255     ENV Test Database  ENVTEST1     fish              FRAB_OBSTRUCTIONS
# 63947     ENV Test Database  ENVTEST1     fish             GIS_FISS_LOCATIONS
# 76515     ENV Test Database  ENVTEST1     fish                  MACRO_REACHES
# 76563     ENV Test Database  ENVTEST1     fish              MACRO_REACHES_LOG
# 76566     ENV Test Database  ENVTEST1     fish         macro_reaches_with_wsc
# 118900    RRS Test Database   RRSTST1  app_rrs           VAR_WIDTH_SUBSECTION
# 120107    ENV Test Database  ENVTEST1     vgis                    veg_ch_01_1
# 120108    ENV Test Database  ENVTEST1     vgis                    veg_ch_01_1
# 120109    ENV Test Database  ENVTEST1     vgis                    veg_ch_01_1
# 120110    ENV Test Database  ENVTEST1     vgis                    veg_ch_01_1
# 120123    ENV Test Database  ENVTEST1     vgis                    veg_ch_01_1
# 120147    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2000
# 120148    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2000
# 120149    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2000
# 120150    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2000
# 120163    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2000
# 120187    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2012
# 120188    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2012
# 120189    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2012
# 120190    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2012
# 120203    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2012
# 120227    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2013
# 120228    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2013
# 120229    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2013
# 120230    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2013
# 120243    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2013
# 120267    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2014
# 120268    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2014
# 120269    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2014
# 120270    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2014
# 120283    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2014
# 120307    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2015
# 120308    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2015
# 120309    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2015
# 120310    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2015
# 120323    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2015
# 120347    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2018
# 120348    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2018
# 120349    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2018
# 120350    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2018
# 120363    ENV Test Database  ENVTEST1     vgis               veg_ch_01_1_2018
# 120387    ENV Test Database  ENVTEST1     vgis                 veg_ch_01_1_99
# 120388    ENV Test Database  ENVTEST1     vgis                 veg_ch_01_1_99
# 120389    ENV Test Database  ENVTEST1     vgis                 veg_ch_01_1_99
# 120390    ENV Test Database  ENVTEST1     vgis                 veg_ch_01_1_99
# 120403    ENV Test Database  ENVTEST1     vgis                 veg_ch_01_1_99
# 120615    ENV Test Database  ENVTEST1     vgis                    veg_eo_16_1
# 120616    ENV Test Database  ENVTEST1     vgis                    veg_eo_16_1
# 120661    ENV Test Database  ENVTEST1     vgis                    veg_ep_12_1
# 120662    ENV Test Database  ENVTEST1     vgis                    veg_ep_12_1
# 120706    ENV Test Database  ENVTEST1     vgis                    veg_ep_12_2
# 120753    ENV Test Database  ENVTEST1     vgis                    veg_et_14_1
# 120754    ENV Test Database  ENVTEST1     vgis                    veg_et_14_1
# 120855    ENV Test Database  ENVTEST1     vgis                    veg_ew_06_1
# 120856    ENV Test Database  ENVTEST1     vgis                    veg_ew_06_1
# 120857    ENV Test Database  ENVTEST1     vgis                    veg_ew_06_1
# 120867    ENV Test Database  ENVTEST1     vgis                    veg_ew_06_2
# 120886    ENV Test Database  ENVTEST1     vgis                    veg_ew_06_3
# 120903    ENV Test Database  ENVTEST1     vgis                    veg_ew_06_4
# 121186    ENV Test Database  ENVTEST1     vgis                    veg_rs_04_1
# 121187    ENV Test Database  ENVTEST1     vgis                    veg_rs_04_1
# 121188    ENV Test Database  ENVTEST1     vgis                    veg_rs_04_1
# 121206    ENV Test Database  ENVTEST1     vgis                    veg_rs_04_2
# 121231    ENV Test Database  ENVTEST1     vgis                    veg_rs_04_3
# 121262    ENV Test Database  ENVTEST1     vgis                    veg_ta_11_2
# 126302    ENV Test Database  ENVTEST1     fish  WATERBODY_COVERAGE_DUPLICATES
# 126310    ENV Test Database  ENVTEST1     fish            WATERBODY_COVERAGES
#
#                            Column  Tag  index
# 7616                  SUBSCRIBER#  NaN      1
# 7618                     ADDRESS#  NaN      3
# 7622                  SUBSCRIBER#  NaN      1
# 7624                     ADDRESS#  NaN      3
# 7632                  SUBSCRIBER#  NaN      0
# 7634                       QUEUE#  NaN      2
# 7636                      SENDER#  NaN      4
# 7637                    TXN_STEP#  NaN      5
# 7647                  SUBSCRIBER#  NaN      1
# 7649                     ADDRESS#  NaN      3
# 8508                      GIS_BL#  NaN      1
# 28133                         S/L  NaN     14
# 28198                         S/L  NaN     14
# 34820                     RESULT#  NaN      2
# 34826                        ALR#  NaN      8
# 34830                     BIOGEO#  NaN     12
# 34837                        IRC#  NaN     19
# 34843                       MGMT#  NaN     25
# 34846                       OPER#  NaN     28
# 34850                    OVERLAY#  NaN     32
# 34853                      OWNER#  NaN     35
# 34858                        PAS#  NaN     40
# 34863                   PLANCELL#  NaN     45
# 34867                    PROVFOR#  NaN     49
# 34872                       PSYU#  NaN     54
# 34876                      RANGE#  NaN     58
# 34882                        REC#  NaN     64
# 34891                    REGDIST#  NaN     73
# 34896                        TSA#  NaN     78
# 51920                     GIS_BL#  NaN      1
# 52104                     GIS_BL#  NaN      2
# 55255                     GIS_BL#  NaN     13
# 63947                     GIS_BL#  NaN      4
# 76515                     GIS_BL#  NaN      1
# 76563                     GIS_BL#  NaN      3
# 76566                     GIS_BL#  NaN      1
# 118900            RETIREMENT DATE  NaN      9
# 120107             CREW_PERSON_#1  NaN     13
# 120108             CREW_PERSON_#2  NaN     14
# 120109             CREW_PERSON_#3  NaN     15
# 120110             CREW_PERSON_#4  NaN     16
# 120123   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120147             CREW_PERSON_#1  NaN     13
# 120148             CREW_PERSON_#2  NaN     14
# 120149             CREW_PERSON_#3  NaN     15
# 120150             CREW_PERSON_#4  NaN     16
# 120163   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120187             CREW_PERSON_#1  NaN     13
# 120188             CREW_PERSON_#2  NaN     14
# 120189             CREW_PERSON_#3  NaN     15
# 120190             CREW_PERSON_#4  NaN     16
# 120203   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120227             CREW_PERSON_#1  NaN     13
# 120228             CREW_PERSON_#2  NaN     14
# 120229             CREW_PERSON_#3  NaN     15
# 120230             CREW_PERSON_#4  NaN     16
# 120243   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120267             CREW_PERSON_#1  NaN     13
# 120268             CREW_PERSON_#2  NaN     14
# 120269             CREW_PERSON_#3  NaN     15
# 120270             CREW_PERSON_#4  NaN     16
# 120283   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120307             CREW_PERSON_#1  NaN     13
# 120308             CREW_PERSON_#2  NaN     14
# 120309             CREW_PERSON_#3  NaN     15
# 120310             CREW_PERSON_#4  NaN     16
# 120323   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120347             CREW_PERSON_#1  NaN     13
# 120348             CREW_PERSON_#2  NaN     14
# 120349             CREW_PERSON_#3  NaN     15
# 120350             CREW_PERSON_#4  NaN     16
# 120363   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120387             CREW_PERSON_#1  NaN     13
# 120388             CREW_PERSON_#2  NaN     14
# 120389             CREW_PERSON_#3  NaN     15
# 120390             CREW_PERSON_#4  NaN     16
# 120403   PLOT_CLUSTER_#_OF_PHOTOS  NaN     29
# 120615             CREW_PERSON_#1  NaN      7
# 120616             CREW_PERSON_#2  NaN      8
# 120661             CREW_PERSON_#1  NaN      8
# 120662             CREW_PERSON_#2  NaN      9
# 120706  SITE_SERIES_AND_COVERAGE#  NaN      8
# 120753             CREW_PERSON_#1  NaN      7
# 120754             CREW_PERSON_#2  NaN      8
# 120855             CREW_PERSON_#1  NaN      7
# 120856             CREW_PERSON_#2  NaN      8
# 120857                  TRANSECT#  NaN      9
# 120867                  TRANSECT#  NaN      5
# 120886                  TRANSECT#  NaN      5
# 120903                  TRANSECT#  NaN      5
# 121186             CREW_PERSON_#1  NaN      7
# 121187             CREW_PERSON_#2  NaN      8
# 121188                  TRANSECT#  NaN      9
# 121206                  TRANSECT#  NaN      5
# 121231                  TRANSECT#  NaN      5
# 121262                      TREE#  NaN      5
# 126302             WATERBODY_KEY#  NaN      5
# 126310             WATERBODY_KEY#  NaN      5

# %% [markdown]
# Okay, now out of all the possible tables and columns we have in DEV, the table above represents all of those that have UPPERCASE column names.
#
# The following envs and schemas are the ones that have uppercase only column names.

# %%
uppercase_only_df['env'].unique()
# Out:
# array(['ENV Test Database', 'DBQ01', 'geobc test database',
#        'RRS Test Database'], dtype=object)

# %%
uppercase_only_df['Schema'].unique()
# Out:
# array(['pscis', 'fish', 'consep', 'csa', 'app_rrs', 'vgis'], dtype=object)

# %%
#Re-write the CSV with the new added column index column
df.to_csv('all_cols.csv')

# %%
# Find unique combinations between the two columns
unique_combinations = df.drop_duplicates(subset=['env', 'Database'])

# Display the unique combinations and count how many there are
print(unique_combinations)
print(f"Number of unique combinations: {len(unique_combinations)}")
# Out:
#                                               Table Name  \
# 0             DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE
# 5      dlhdev.lhousedev.fdw_ods_fta_replication.aac_a...
# 308        ENV Test Database.ENVTEST1.acat.ACAT_CONTACTS
# 623            geobc test database.GEOTST.mascot.ACCOUNT
# 5808        MEMTST1.MEMTST.app_mms_interface.APPLICATION
# 6100   RRS Test Database.RRSTST1.app_rrs.APPLICATION_...
# 9091   ODS.odsdev.ats_replication.ats_athn_close_reas...
# 12288  Mineral Titles Online TEST Database.MTOTEST.co...
# 32746  ENV Test Database.ENVTEST1.swis."Count_entered...
#
#                                        env   Database  \
# 0                                    DBQ01      DBQ01
# 5                                   dlhdev  lhousedev
# 308                      ENV Test Database   ENVTEST1
# 623                    geobc test database     GEOTST
# 5808                               MEMTST1     MEMTST
# 6100                     RRS Test Database    RRSTST1
# 9091                                   ODS     odsdev
# 12288  Mineral Titles Online TEST Database    MTOTEST
# 32746                              #SPILL!        NaN
#
#                         Schema                        Table  \
# 0                          the   AAC_ADJUSTMENT_REASON_CODE
# 5      fdw_ods_fta_replication        aac_allocation_amount
# 308                       acat                ACAT_CONTACTS
# 623                     mascot                      ACCOUNT
# 5808         app_mms_interface                  APPLICATION
# 6100                   app_rrs         APPLICATION_BULLETIN
# 9091           ats_replication  ats_athn_close_reason_codes
# 12288                     corp                BCGS_20K_GRID
# 32746                      NaN                          NaN
#
#                            Column                                  Tag  index
# 0      aac_adjustment_reason_code  Test Classification.Ignore this tag      0
# 5        aac_allocation_amount_id                                  NaN      0
# 308                    contact_id                                  NaN      0
# 623                    account_id                                  NaN      0
# 5808                    messageid                                  NaN      0
# 6100    application_bulletin_guid                                  NaN      0
# 9091       athn_close_reason_code                                  NaN      0
# 12288                       fcode                                  NaN      0
# 32746                  created_by                                  NaN      0
# Number of unique combinations: 9

# %%
# Find unique combinations and their counts
combination_counts = df.groupby(['env', 'Database']).size().reset_index(name='count')

# Create a dictionary with the combinations as keys and their counts as values
combo_dict = {(row['env'], row['Database']): row['count'] for _, row in combination_counts.iterrows()}

# Display the dictionary
print(combo_dict)

# Print each combination and its count in a vertically stacked list
for combo, count in combo_dict.items():
    print(f"Combination {combo}: {count}")
# Out:
# {('DBQ01', 'DBQ01'): 62149, ('ENV Test Database', 'ENVTEST1'): 45394, ('MEMTST1', 'MEMTST'): 803, ('Mineral Titles Online TEST Database', 'MTOTEST'): 2392, ('ODS', 'odsdev'): 683, ('RRS Test Database', 'RRSTST1'): 2445, ('dlhdev', 'lhousedev'): 1779, ('geobc test database', 'GEOTST'): 16917}
# Combination ('DBQ01', 'DBQ01'): 62149
# Combination ('ENV Test Database', 'ENVTEST1'): 45394
# Combination ('MEMTST1', 'MEMTST'): 803
# Combination ('Mineral Titles Online TEST Database', 'MTOTEST'): 2392
# Combination ('ODS', 'odsdev'): 683
# Combination ('RRS Test Database', 'RRSTST1'): 2445
# Combination ('dlhdev', 'lhousedev'): 1779
# Combination ('geobc test database', 'GEOTST'): 16917

# %%
df['env'].unique()
# Out:
# array(['DBQ01', 'dlhdev', 'ENV Test Database', 'geobc test database',
#        'MEMTST1', 'RRS Test Database', 'ODS',
#        'Mineral Titles Online TEST Database', '#SPILL!'], dtype=object)

# %%
df['Database'].unique()
# Out:
# array(['DBQ01', 'lhousedev', 'ENVTEST1', 'GEOTST', 'MEMTST', 'RRSTST1',
#        'odsdev', 'MTOTEST', nan], dtype=object)

# %%
df['Schema'].unique()
# Out:
# array(['the', 'fdw_ods_fta_replication', 'acat', 'fish', 'vgis', 'mascot',
#        'app_pefp', 'ems_public', 'webade', 'consep', 'sis', 'aps',
#        'akharagh', 'mascot_test', 'swis', 'information_schema', 'fadm',
#        'wimsi', 'ngps', 'csa', 'app_mms_interface', 'app_rrs', 'print',
#        'odm', 'pscis', 'esri', 'rep_bcparks', 'ars', 'swis_archive',
#        'ata', 'ats', 'fdw_ods_ats_replication', 'ats_replication',
#        'test_ats_replication', 'audsys', 'wells', 'barts', 'bath',
#        'bcemap', 'fdw_ods_pmt_gis_analysis', 'corp', 'bei', 'eirs',
#        'ceei2', 'cbd', 'ccsd', 'ceei', 'odm_mtr', 'bcgnis', 'melp',
#        'paso', 'cms', 'cms_client', 'cnar', 'mta_spatial', 'enf', 'wtr',
#        'cwi_spi_dc', 'epic', nan, 'crs', 'cwi_spi_opd', 'cwi_txn', 'fiss',
#        'hdms', 'cogix', 'pmt_dpl', 'pmt_sandbox', 'ems', 'epic_prod_imp',
#        'lexis_replication', 'pmt_dal', 'isdut', 'fdis', 'fhas',
#        'fta_replication', 'fms', 'gator', 'geomark', 'leh', 'gys', 'mta',
#        'p2sry', 'inap', 'jill', 'mta_geodb', 'moe_pref', 'mtec', 'fnlg',
#        'fdw_ods_rrs_replication', 'ocers', 'oss', 'par', 'pss', 'r2pub',
#        'wildtele', 'rar', 'hpsry', 'rrs_replication', 'rits', 'mta_ilrr',
#        'app_sgw', 'ssdb', 'tantalis', 'wml_app', 'tipdb', 'tr',
#        'csnr_admin_user', 'vmad', 'watroute', 'wins', 'wis', 'rep_waste'],
#       dtype=object)

# %% [markdown]
# Okay, let's see what env/schema combos are present on the CSV of compiled secuirty classification data

# %%
df2 = pd.read_csv('reference_csvs/cmp.csv')
df2.head()
# Out:
#   Database Schema                  Table                      Column     Tag  \
# 0    DBP01    THE  AAC_ALLOCATION_AMOUNT    AAC_ALLOCATION_AMOUNT_ID  PUBLIC
# 1    DBP01    THE  AAC_ALLOCATION_AMOUNT  AAC_ADJUSTMENT_REASON_CODE  PUBLIC
# 2    DBP01    THE  AAC_ALLOCATION_AMOUNT    AAC_ALLOCATION_PERIOD_ID  PUBLIC
# 3    DBP01    THE  AAC_ALLOCATION_AMOUNT    ALLOWABLE_AREA_TYPE_CODE  PUBLIC
# 4    DBP01    THE  AAC_ALLOCATION_AMOUNT     ALLOWABLE_CUT_TYPE_CODE  PUBLIC
#
#   Data Type Column Length Nullable  Rows in Table  Notes How to Mask  \
# 0    NUMBER            10        N         5891.0    NaN         NaN
# 1  VARCHAR2             4        N            NaN    NaN         NaN
# 2    NUMBER            10        N            NaN    NaN         NaN
# 3  VARCHAR2             3        N            NaN    NaN         NaN
# 4  VARCHAR2             3        N            NaN    NaN         NaN
#
#   How it was Masked Comments
# 0               NaN      NaN
# 1               NaN      NaN
# 2               NaN      NaN
# 3               NaN      NaN
# 4               NaN      NaN

# %%
df2['Database'].unique()
# Out:
# array(['DBP01', 'GEOPRD'], dtype=object)

# %%
df2['Schema'].unique()
# Out:
# array(['THE', 'ATS'], dtype=object)

# %% [markdown]
# Great, from the above 2 code blocks we can see that the schemas and Databases that have security classification information will not need extra formatting to match the ones with uppercase as outlined further above. This saves a bit of work.

# %%
# Create 'ENV' column based on 'Database' column using np.where()
df2['ENV'] = np.where(df2['Database'] == 'DBP01', 'DBQ01', 'geobc test database')

# %% [markdown]
# And because DEV does not contain DBP01, we will go ahead and assume we change DBP01 tpo DBQ01 to make it compatible with DEV

# %%
df2.head()
# Out:
#   Database Schema                  Table                      Column     Tag  \
# 0    DBP01    THE  AAC_ALLOCATION_AMOUNT    AAC_ALLOCATION_AMOUNT_ID  PUBLIC
# 1    DBP01    THE  AAC_ALLOCATION_AMOUNT  AAC_ADJUSTMENT_REASON_CODE  PUBLIC
# 2    DBP01    THE  AAC_ALLOCATION_AMOUNT    AAC_ALLOCATION_PERIOD_ID  PUBLIC
# 3    DBP01    THE  AAC_ALLOCATION_AMOUNT    ALLOWABLE_AREA_TYPE_CODE  PUBLIC
# 4    DBP01    THE  AAC_ALLOCATION_AMOUNT     ALLOWABLE_CUT_TYPE_CODE  PUBLIC
#
#   Data Type Column Length Nullable  Rows in Table  Notes How to Mask  \
# 0    NUMBER            10        N         5891.0    NaN         NaN
# 1  VARCHAR2             4        N            NaN    NaN         NaN
# 2    NUMBER            10        N            NaN    NaN         NaN
# 3  VARCHAR2             3        N            NaN    NaN         NaN
# 4  VARCHAR2             3        N            NaN    NaN         NaN
#
#   How it was Masked Comments    ENV
# 0               NaN      NaN  DBQ01
# 1               NaN      NaN  DBQ01
# 2               NaN      NaN  DBQ01
# 3               NaN      NaN  DBQ01
# 4               NaN      NaN  DBQ01

# %%
df2['FQN'] = df2['ENV']+'.'+df2['Database']+'.'+df2['Schema'].str.lower()+'.'+df2['Table']+'.'+df2['Column']
df2['FQN'] = df2['FQN'].str.replace('DBP01', 'DBQ01')

# %%
df2['Table Name'] = df2['ENV']+'.'+df2['Database']+'.'+df2['Schema'].str.lower()+'.'+df2['Table']
df2['Table Name'] = df2['Table Name'].str.replace('DBP01', 'DBQ01')
df2['index'] = df2.groupby('Table Name').cumcount()

# %%
df2.head(10)
# Out:
#   Database Schema                  Table                      Column  \
# 0    DBP01    THE  AAC_ALLOCATION_AMOUNT    AAC_ALLOCATION_AMOUNT_ID
# 1    DBP01    THE  AAC_ALLOCATION_AMOUNT  AAC_ADJUSTMENT_REASON_CODE
# 2    DBP01    THE  AAC_ALLOCATION_AMOUNT    AAC_ALLOCATION_PERIOD_ID
# 3    DBP01    THE  AAC_ALLOCATION_AMOUNT    ALLOWABLE_AREA_TYPE_CODE
# 4    DBP01    THE  AAC_ALLOCATION_AMOUNT     ALLOWABLE_CUT_TYPE_CODE
# 5    DBP01    THE  AAC_ALLOCATION_AMOUNT           ALLOCATION_AMOUNT
# 6    DBP01    THE  AAC_ALLOCATION_AMOUNT          ADJUSTMENT_COMMENT
# 7    DBP01    THE  AAC_ALLOCATION_AMOUNT              REVISION_COUNT
# 8    DBP01    THE  AAC_ALLOCATION_AMOUNT                ENTRY_USERID
# 9    DBP01    THE  AAC_ALLOCATION_AMOUNT             ENTRY_TIMESTAMP
#
#             Tag Data Type Column Length Nullable  Rows in Table  Notes  \
# 0        PUBLIC    NUMBER            10        N         5891.0    NaN
# 1        PUBLIC  VARCHAR2             4        N            NaN    NaN
# 2        PUBLIC    NUMBER            10        N            NaN    NaN
# 3        PUBLIC  VARCHAR2             3        N            NaN    NaN
# 4        PUBLIC  VARCHAR2             3        N            NaN    NaN
# 5  CONFIDENTIAL    NUMBER          14,4        N            NaN    NaN
# 6  CONFIDENTIAL  VARCHAR2          4000        Y            NaN    NaN
# 7        PUBLIC    NUMBER             5        N            NaN    NaN
# 8   PROTECTED_A  VARCHAR2            30        N            NaN    NaN
# 9        PUBLIC      DATE             7        N            NaN    NaN
#
#                How to Mask                                  How it was Masked  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6  Set to NULL or Scramble  THE@masking.nrs.bcgov> alter trigger the.aac_b...
# 7                      NaN                                   Trigger altered.
# 8     Set to D or Scramble  THE@masking.nrs.bcgov> update aac_allocation_a...
# 9                      NaN                                 5919 rows updated.
#
#   Comments    ENV                                                FQN  \
# 0      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ALLO...
# 1      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ADJU...
# 2      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ALLO...
# 3      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOWABL...
# 4      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOWABL...
# 5      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOCATI...
# 6      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ADJUSTME...
# 7      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.REVISION...
# 8      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ENTRY_US...
# 9      NaN  DBQ01  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ENTRY_TI...
#
#                               Table Name  index
# 0  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      0
# 1  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      1
# 2  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      2
# 3  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      3
# 4  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      4
# 5  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      5
# 6  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      6
# 7  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      7
# 8  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      8
# 9  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT      9

# %%
df3 = df2[['Table Name','Tag','index','Column','FQN']]

# %%
df3.head()
# Out:
#                               Table Name     Tag  index  \
# 0  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  PUBLIC      0
# 1  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  PUBLIC      1
# 2  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  PUBLIC      2
# 3  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  PUBLIC      3
# 4  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  PUBLIC      4
#
#                        Column  \
# 0    AAC_ALLOCATION_AMOUNT_ID
# 1  AAC_ADJUSTMENT_REASON_CODE
# 2    AAC_ALLOCATION_PERIOD_ID
# 3    ALLOWABLE_AREA_TYPE_CODE
# 4     ALLOWABLE_CUT_TYPE_CODE
#
#                                                  FQN
# 0  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ALLO...
# 1  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ADJU...
# 2  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ALLO...
# 3  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOWABL...
# 4  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOWABL...

# %%
df.head()
# Out:
#                                    Table Name    env Database Schema  \
# 0  DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE  DBQ01    DBQ01    the
# 1  DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE  DBQ01    DBQ01    the
# 2  DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE  DBQ01    DBQ01    the
# 3  DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE  DBQ01    DBQ01    the
# 4  DBQ01.DBQ01.the.AAC_ADJUSTMENT_REASON_CODE  DBQ01    DBQ01    the
#
#                         Table                      Column  \
# 0  AAC_ADJUSTMENT_REASON_CODE  aac_adjustment_reason_code
# 1  AAC_ADJUSTMENT_REASON_CODE                 description
# 2  AAC_ADJUSTMENT_REASON_CODE              effective_date
# 3  AAC_ADJUSTMENT_REASON_CODE                 expiry_date
# 4  AAC_ADJUSTMENT_REASON_CODE            update_timestamp
#
#                                    Tag  index
# 0  Test Classification.Ignore this tag      0
# 1  Test Classification.Ignore this tag      1
# 2                                  NaN      2
# 3                                  NaN      3
# 4                                  NaN      4

# %%
merged_df = pd.merge(df,df3, on=['Table Name','index'])

# %%
# Define the mapping
mapping = {
    'PROTECTED_A': 'Data Security Classification.Protected A',
    'PROTECTED_B': 'Data Security Classification.Protected B',
    'PROTECTED_C': 'Data Security Classification.Protected C',
    'PUBLIC': 'Data Security Classification.Public',
    'CONFIDENTIAL': 'Data Security Classification.Confidential'
}

# Map values in the columns using the mapping dictionary
merged_df['Tag_x'] = merged_df['Tag_y'].map(mapping)

# %%
merged_df['Tag_y'].unique()
# Out:
# array(['PUBLIC', 'CONFIDENTIAL', 'PROTECTED_A'], dtype=object)

# %%
merged_df['Tag_x'].unique()
# Out:
# array(['Data Security Classification.Public',
#        'Data Security Classification.Confidential',
#        'Data Security Classification.Protected A'], dtype=object)

# %%
merged_df[merged_df['Table']=='AAC_ALLOCATION_AMOUNT']
# Out:
#                                Table Name    env Database Schema  \
# 5   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 6   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 7   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 8   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 9   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 10  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 11  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 12  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 13  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 14  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 15  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
# 16  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT  DBQ01    DBQ01    the
#
#                     Table                    Column_x  \
# 5   AAC_ALLOCATION_AMOUNT    aac_allocation_amount_id
# 6   AAC_ALLOCATION_AMOUNT  aac_adjustment_reason_code
# 7   AAC_ALLOCATION_AMOUNT    aac_allocation_period_id
# 8   AAC_ALLOCATION_AMOUNT    allowable_area_type_code
# 9   AAC_ALLOCATION_AMOUNT     allowable_cut_type_code
# 10  AAC_ALLOCATION_AMOUNT           allocation_amount
# 11  AAC_ALLOCATION_AMOUNT          adjustment_comment
# 12  AAC_ALLOCATION_AMOUNT              revision_count
# 13  AAC_ALLOCATION_AMOUNT                entry_userid
# 14  AAC_ALLOCATION_AMOUNT             entry_timestamp
# 15  AAC_ALLOCATION_AMOUNT               update_userid
# 16  AAC_ALLOCATION_AMOUNT            update_timestamp
#
#                                         Tag_x  index         Tag_y  \
# 5         Data Security Classification.Public      0        PUBLIC
# 6         Data Security Classification.Public      1        PUBLIC
# 7         Data Security Classification.Public      2        PUBLIC
# 8         Data Security Classification.Public      3        PUBLIC
# 9         Data Security Classification.Public      4        PUBLIC
# 10  Data Security Classification.Confidential      5  CONFIDENTIAL
# 11  Data Security Classification.Confidential      6  CONFIDENTIAL
# 12        Data Security Classification.Public      7        PUBLIC
# 13   Data Security Classification.Protected A      8   PROTECTED_A
# 14        Data Security Classification.Public      9        PUBLIC
# 15   Data Security Classification.Protected A     10   PROTECTED_A
# 16        Data Security Classification.Public     11        PUBLIC
#
#                       Column_y  \
# 5     AAC_ALLOCATION_AMOUNT_ID
# 6   AAC_ADJUSTMENT_REASON_CODE
# 7     AAC_ALLOCATION_PERIOD_ID
# 8     ALLOWABLE_AREA_TYPE_CODE
# 9      ALLOWABLE_CUT_TYPE_CODE
# 10           ALLOCATION_AMOUNT
# 11          ADJUSTMENT_COMMENT
# 12              REVISION_COUNT
# 13                ENTRY_USERID
# 14             ENTRY_TIMESTAMP
# 15               UPDATE_USERID
# 16            UPDATE_TIMESTAMP
#
#                                                   FQN
# 5   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ALLO...
# 6   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ADJU...
# 7   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.AAC_ALLO...
# 8   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOWABL...
# 9   DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOWABL...
# 10  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ALLOCATI...
# 11  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ADJUSTME...
# 12  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.REVISION...
# 13  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ENTRY_US...
# 14  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.ENTRY_TI...
# 15  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.UPDATE_U...
# 16  DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT.UPDATE_T...

# %%
len(merged_df[merged_df['Tag_y']=='CONFIDENTIAL'])
# Out:
# 306

# %% [markdown]
# Looks like everything is in order so let's apply the secuirty classification tags!

# %%
# Example: Checking if the table exists before applying tags
for index, row in merged_df[merged_df['Tag_y']=='CONFIDENTIAL'].iterrows():
    table_fqn = row['Table Name']
    column_index = row['index']
    tag_fqn = row['Tag_x']

    # Construct the API URL for checking if the table exists
    url_check = f"https://nr-data-catalogue-test.apps.emerald.devops.gov.bc.ca/api/v1/tables/name/{table_fqn}?fields=columns,tags"

    # Send a GET request to check if the table exists
    response_check = requests.get(url_check, headers=headers_get)

    if response_check.status_code == 200:
        print(f"Table {table_fqn} exists. Proceeding to add tag.")

        # Construct the API URL
        url_fqn = f"https://nr-data-catalogue-{env}.apps.emerald.devops.gov.bc.ca/api/v1/tables/name/{table_fqn}?fields=columns,tags"

        # JSON body for adding a tag to the specific column
        data_patch = [
            {
                "op": "add",
                "path": f"/columns/{column_index}/tags",
                "value": [
                    {
                        "tagFQN": tag_fqn,
                        "labelType": "Manual",
                        "state": "Confirmed"
                    }
                ]
            }
        ]

        # Send the PATCH request to add the tag
        response = requests.patch(url_fqn, headers=headers_patch, json=data_patch)
        time.sleep(1)

        if response.status_code == 200:
            print(f"Tag added successfully for {table_fqn} - column {column_index}!")
        else:
            print(f"Failed to add tag for {table_fqn} - column {column_index}: {response.status_code}")
            print(response.json())
    else:
        print(f"Table {table_fqn} not found. Skipping this entry.")
# Out:
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT - column 5!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT - column 6!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT - column 3!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT - column 6!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT - column 7!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT - column 8!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_AMOUNT_AUDIT - column 9!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_PERIOD exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_PERIOD - column 2!
# Table DBQ01.DBQ01.the.AAC_ALLOCATION_PERIOD_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.AAC_ALLOCATION_PERIOD_AUDIT - column 4!
# Table DBQ01.DBQ01.the.BLANKET_ROAD_MARK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.BLANKET_ROAD_MARK - column 6!
# Table DBQ01.DBQ01.the.BLANKET_ROAD_MARK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.BLANKET_ROAD_MARK - column 7!
# Table DBQ01.DBQ01.the.CHART_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK - column 3!
# Table DBQ01.DBQ01.the.CHART_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK - column 4!
# Table DBQ01.DBQ01.the.CHART_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK - column 5!
# Table DBQ01.DBQ01.the.CHART_BLOCK_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.CHART_BLOCK_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK_AMEND_GEOM - column 6!
# Table DBQ01.DBQ01.the.CHART_BLOCK_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK_AMEND_GEOM - column 7!
# Table DBQ01.DBQ01.the.CHART_BLOCK_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK_GEOM - column 4!
# Table DBQ01.DBQ01.the.CHART_BLOCK_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK_GEOM - column 5!
# Table DBQ01.DBQ01.the.CHART_BLOCK_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CHART_BLOCK_GEOM - column 6!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 2!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 4!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 5!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 6!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 7!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 8!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 9!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 10!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 11!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 12!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 13!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 14!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 15!
# Table DBQ01.DBQ01.the.CLIENT_LOCATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CLIENT_LOCATION - column 19!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 3!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 5!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 6!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 7!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 9!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 10!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 11!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 12!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 13!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 16!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE - column 17!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE_GEOM - column 3!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE_GEOM - column 4!
# Table DBQ01.DBQ01.the.COMMUNICATION_SITE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.COMMUNICATION_SITE_GEOM - column 5!
# Table DBQ01.DBQ01.the.CUT_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK - column 7!
# Table DBQ01.DBQ01.the.CUT_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK - column 8!
# Table DBQ01.DBQ01.the.CUT_BLOCK_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_AMEND_GEOM - column 3!
# Table DBQ01.DBQ01.the.CUT_BLOCK_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_AMEND_GEOM - column 4!
# Table DBQ01.DBQ01.the.CUT_BLOCK_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.CUT_BLOCK_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_AUDIT - column 8!
# Table DBQ01.DBQ01.the.CUT_BLOCK_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_AUDIT - column 9!
# Table DBQ01.DBQ01.the.CUT_BLOCK_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_AUDIT - column 12!
# Table DBQ01.DBQ01.the.CUT_BLOCK_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_CLIENT - column 3!
# Table DBQ01.DBQ01.the.CUT_BLOCK_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_CLIENT - column 4!
# Table DBQ01.DBQ01.the.CUT_BLOCK_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_GEOM - column 2!
# Table DBQ01.DBQ01.the.CUT_BLOCK_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_GEOM - column 3!
# Table DBQ01.DBQ01.the.CUT_BLOCK_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_GEOM - column 4!
# Table DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT - column 1!
# Table DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT - column 2!
# Table DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT - column 3!
# Table DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUT_BLOCK_KEY_EVENT - column 4!
# Table DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT - column 2!
# Table DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT - column 3!
# Table DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT - column 4!
# Table DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.CUTTING_PERMIT_POSTPONEMENT - column 5!
# Table DBQ01.DBQ01.the.FEATURE_CLASSES exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FEATURE_CLASSES - column 15!
# Table DBQ01.DBQ01.the.FEATURE_CLASSES exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FEATURE_CLASSES - column 20!
# Table DBQ01.DBQ01.the.FEATURE_CLASSES exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FEATURE_CLASSES - column 21!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 1!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 2!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 3!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 6!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 8!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 10!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 12!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 13!
# Table DBQ01.DBQ01.the.FOREST_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_CLIENT - column 14!
# Table DBQ01.DBQ01.the.FOREST_FILE_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_FILE_CLIENT - column 5!
# Table DBQ01.DBQ01.the.FOREST_FILE_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FOREST_FILE_CLIENT - column 6!
# Table DBQ01.DBQ01.the.FREE_USE_PERMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FREE_USE_PERMIT - column 3!
# Table DBQ01.DBQ01.the.FREE_USE_PERMIT_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FREE_USE_PERMIT_GEOM - column 3!
# Table DBQ01.DBQ01.the.FREE_USE_PERMIT_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FREE_USE_PERMIT_GEOM - column 4!
# Table DBQ01.DBQ01.the.FREE_USE_PERMIT_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FREE_USE_PERMIT_GEOM - column 5!
# Table DBQ01.DBQ01.the.FSR_DECLARATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION - column 3!
# Table DBQ01.DBQ01.the.FSR_DECLARATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION - column 4!
# Table DBQ01.DBQ01.the.FSR_DECLARATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION - column 7!
# Table DBQ01.DBQ01.the.FSR_DECLARATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION - column 8!
# Table DBQ01.DBQ01.the.FSR_DECLARATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION - column 9!
# Table DBQ01.DBQ01.the.FSR_DECLARATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION_GEOM - column 4!
# Table DBQ01.DBQ01.the.FSR_DECLARATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DECLARATION_GEOM - column 5!
# Table DBQ01.DBQ01.the.FSR_DEDICATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION - column 3!
# Table DBQ01.DBQ01.the.FSR_DEDICATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION - column 4!
# Table DBQ01.DBQ01.the.FSR_DEDICATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION - column 6!
# Table DBQ01.DBQ01.the.FSR_DEDICATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION - column 8!
# Table DBQ01.DBQ01.the.FSR_DEDICATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION - column 9!
# Table DBQ01.DBQ01.the.FSR_DEDICATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION - column 10!
# Table DBQ01.DBQ01.the.FSR_DEDICATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION_GEOM - column 4!
# Table DBQ01.DBQ01.the.FSR_DEDICATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION_GEOM - column 5!
# Table DBQ01.DBQ01.the.FSR_DEDICATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_DEDICATION_GEOM - column 6!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_GEOM - column 4!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_GEOM - column 5!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED - column 3!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED - column 7!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED - column 9!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED - column 10!
# Table DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GAZETTE_UNSURVEYED - column 11!
# Table DBQ01.DBQ01.the.FSR_GRAVEL_PIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GRAVEL_PIT - column 9!
# Table DBQ01.DBQ01.the.FSR_GRAVEL_PIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GRAVEL_PIT - column 10!
# Table DBQ01.DBQ01.the.FSR_GRAVEL_PIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GRAVEL_PIT - column 11!
# Table DBQ01.DBQ01.the.FSR_GRAVEL_PIT_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GRAVEL_PIT_GEOM - column 4!
# Table DBQ01.DBQ01.the.FSR_GRAVEL_PIT_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GRAVEL_PIT_GEOM - column 5!
# Table DBQ01.DBQ01.the.FSR_GRAVEL_PIT_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FSR_GRAVEL_PIT_GEOM - column 6!
# Table DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST - column 6!
# Table DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST - column 9!
# Table DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST - column 10!
# Table DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST - column 11!
# Table DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST - column 12!
# Table DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.FTA_RANGE_BILL_REQUEST - column 13!
# Table DBQ01.DBQ01.the.HARVEST_AUTHORITY_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_AUTHORITY_AMEND_GEOM - column 3!
# Table DBQ01.DBQ01.the.HARVEST_AUTHORITY_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_AUTHORITY_AMEND_GEOM - column 4!
# Table DBQ01.DBQ01.the.HARVEST_AUTHORITY_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_AUTHORITY_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.HARVEST_AUTHORITY_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_AUTHORITY_GEOM - column 2!
# Table DBQ01.DBQ01.the.HARVEST_AUTHORITY_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_AUTHORITY_GEOM - column 3!
# Table DBQ01.DBQ01.the.HARVEST_AUTHORITY_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_AUTHORITY_GEOM - column 4!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 1!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 2!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 3!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 4!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 5!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 6!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 7!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 8!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 9!
# Table DBQ01.DBQ01.the.HARVEST_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVEST_COMMIT - column 10!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 11!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 12!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 13!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 14!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 15!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 16!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY - column 28!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 10!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 20!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 21!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 22!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 23!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 24!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 25!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 29!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_AUDIT - column 31!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_CLIENT - column 5!
# Table DBQ01.DBQ01.the.HARVESTING_AUTHORITY_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.HARVESTING_AUTHORITY_CLIENT - column 6!
# Table DBQ01.DBQ01.the.LAND_USE_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LAND_USE_AMEND_GEOM - column 3!
# Table DBQ01.DBQ01.the.LAND_USE_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LAND_USE_AMEND_GEOM - column 4!
# Table DBQ01.DBQ01.the.LAND_USE_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LAND_USE_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.LAND_USE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LAND_USE_GEOM - column 1!
# Table DBQ01.DBQ01.the.LAND_USE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LAND_USE_GEOM - column 2!
# Table DBQ01.DBQ01.the.LAND_USE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LAND_USE_GEOM - column 3!
# Table DBQ01.DBQ01.the.LIVESTOCK_ROTATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LIVESTOCK_ROTATION - column 4!
# Table DBQ01.DBQ01.the.LIVESTOCK_ROTATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.LIVESTOCK_ROTATION - column 5!
# Table DBQ01.DBQ01.the.MANAGED_LICENCE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MANAGED_LICENCE - column 8!
# Table DBQ01.DBQ01.the.MANAGED_LICENCE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MANAGED_LICENCE_GEOM - column 5!
# Table DBQ01.DBQ01.the.MANAGED_LICENCE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MANAGED_LICENCE_GEOM - column 6!
# Table DBQ01.DBQ01.the.MANAGED_LICENCE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MANAGED_LICENCE_GEOM - column 7!
# Table DBQ01.DBQ01.the.MAP_NOTATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_NOTATION - column 12!
# Table DBQ01.DBQ01.the.MAP_NOTATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_NOTATION - column 13!
# Table DBQ01.DBQ01.the.MAP_NOTATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_NOTATION_GEOM - column 4!
# Table DBQ01.DBQ01.the.MAP_NOTATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_NOTATION_GEOM - column 5!
# Table DBQ01.DBQ01.the.MAP_NOTATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_NOTATION_GEOM - column 6!
# Table DBQ01.DBQ01.the.MAP_NOTATION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_NOTATION_GEOM - column 7!
# Table DBQ01.DBQ01.the.MAP_REPORT_CONFLICT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_REPORT_CONFLICT - column 1!
# Table DBQ01.DBQ01.the.MAP_REPORT_CONFLICT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_REPORT_CONFLICT - column 3!
# Table DBQ01.DBQ01.the.MAP_REPORT_CONFLICT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.MAP_REPORT_CONFLICT - column 6!
# Table DBQ01.DBQ01.the.NON_STATUS_ROAD exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.NON_STATUS_ROAD - column 6!
# Table DBQ01.DBQ01.the.NSR_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.NSR_GEOM - column 4!
# Table DBQ01.DBQ01.the.NSR_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.NSR_GEOM - column 5!
# Table DBQ01.DBQ01.the.OIL_AND_GAS_AUTHORITY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OIL_AND_GAS_AUTHORITY - column 12!
# Table DBQ01.DBQ01.the.OIL_AND_GAS_COMMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OIL_AND_GAS_COMMENT - column 2!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 9!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 11!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 12!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 16!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 17!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 18!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 19!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 20!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 21!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 22!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 23!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 24!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 25!
# Table DBQ01.DBQ01.the.OPENING exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.OPENING - column 27!
# Table DBQ01.DBQ01.the.PERMIT_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PERMIT_BLOCK - column 2!
# Table DBQ01.DBQ01.the.PERMIT_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PERMIT_BLOCK - column 3!
# Table DBQ01.DBQ01.the.PERMIT_BLOCK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PERMIT_BLOCK - column 5!
# Table DBQ01.DBQ01.the.PIPELINE_SEGMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PIPELINE_SEGMENT - column 7!
# Table DBQ01.DBQ01.the.PIPELINE_SEGMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PIPELINE_SEGMENT - column 11!
# Table DBQ01.DBQ01.the.POINT_OF_TERMINATION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.POINT_OF_TERMINATION - column 2!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE - column 22!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE - column 28!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE - column 29!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_CERTIFICATE - column 30!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_CLIENT - column 5!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_CLIENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_CLIENT - column 6!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS - column 28!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS - column 29!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS - column 30!
# Table DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PRIVATE_MARK_ERRORS - column 36!
# Table DBQ01.DBQ01.the.PROVFOREST_NOTE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PROVFOREST_NOTE - column 2!
# Table DBQ01.DBQ01.the.PROV_FOREST_USE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PROV_FOREST_USE - column 1!
# Table DBQ01.DBQ01.the.PROV_FOREST_USE_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PROV_FOREST_USE_AUDIT - column 2!
# Table DBQ01.DBQ01.the.PROV_FOREST_USE_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PROV_FOREST_USE_AUDIT - column 3!
# Table DBQ01.DBQ01.the.PULPWOOD_AGREE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PULPWOOD_AGREE - column 1!
# Table DBQ01.DBQ01.the.PULPWOOD_AGREE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PULPWOOD_AGREE - column 2!
# Table DBQ01.DBQ01.the.PULPWOOD_AGREE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.PULPWOOD_AGREE - column 3!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 2!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 3!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 4!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 6!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 7!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 8!
# Table DBQ01.DBQ01.the.RANGE_PROVISION exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_PROVISION - column 9!
# Table DBQ01.DBQ01.the.RANGE_TENURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE - column 4!
# Table DBQ01.DBQ01.the.RANGE_TENURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE - column 6!
# Table DBQ01.DBQ01.the.RANGE_TENURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE - column 7!
# Table DBQ01.DBQ01.the.RANGE_TENURE_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE_AMEND_GEOM - column 3!
# Table DBQ01.DBQ01.the.RANGE_TENURE_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE_AMEND_GEOM - column 4!
# Table DBQ01.DBQ01.the.RANGE_TENURE_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.RANGE_TENURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE_GEOM - column 3!
# Table DBQ01.DBQ01.the.RANGE_TENURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE_GEOM - column 4!
# Table DBQ01.DBQ01.the.RANGE_TENURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RANGE_TENURE_GEOM - column 5!
# Table DBQ01.DBQ01.the.REAL_PROPERTY_PROJ_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.REAL_PROPERTY_PROJ_GEOM - column 3!
# Table DBQ01.DBQ01.the.REAL_PROPERTY_PROJ_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.REAL_PROPERTY_PROJ_GEOM - column 4!
# Table DBQ01.DBQ01.the.REAL_PROPERTY_PROJ_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.REAL_PROPERTY_PROJ_GEOM - column 5!
# Table DBQ01.DBQ01.the.RECREATION_AGREEMENT_HOLDER exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_AGREEMENT_HOLDER - column 4!
# Table DBQ01.DBQ01.the.RECREATION_AGREEMENT_HOLDER exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_AGREEMENT_HOLDER - column 5!
# Table DBQ01.DBQ01.the.RECREATION_COMMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_COMMENT - column 4!
# Table DBQ01.DBQ01.the.RECREATION_DEF_CS_RPR_HISTORY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_DEF_CS_RPR_HISTORY - column 3!
# Table DBQ01.DBQ01.the.RECREATION_DEF_CS_RPR_HISTORY exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_DEF_CS_RPR_HISTORY - column 4!
# Table DBQ01.DBQ01.the.RECREATION_DEFINED_CAMPSITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_DEFINED_CAMPSITE - column 2!
# Table DBQ01.DBQ01.the.RECREATION_DEFINED_CAMPSITE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_DEFINED_CAMPSITE - column 4!
# Table DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM - column 3!
# Table DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM - column 4!
# Table DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM - column 5!
# Table DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_MAP_FEATURE_GEOM - column 6!
# Table DBQ01.DBQ01.the.RECREATION_OBJECTIVE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_OBJECTIVE - column 2!
# Table DBQ01.DBQ01.the.RECREATION_PROJECT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_PROJECT - column 11!
# Table DBQ01.DBQ01.the.RECREATION_PROJECT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_PROJECT - column 18!
# Table DBQ01.DBQ01.the.RECREATION_STRUCTURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_STRUCTURE - column 9!
# Table DBQ01.DBQ01.the.RECREATION_STRUCTURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_STRUCTURE - column 12!
# Table DBQ01.DBQ01.the.RECREATION_STRUCTURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_STRUCTURE - column 13!
# Table DBQ01.DBQ01.the.RECREATION_TRAIL_SEGMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_TRAIL_SEGMENT - column 7!
# Table DBQ01.DBQ01.the.RECREATION_TRAIL_SEGMENT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.RECREATION_TRAIL_SEGMENT - column 8!
# Table DBQ01.DBQ01.the.ROAD_PERMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_PERMIT - column 6!
# Table DBQ01.DBQ01.the.ROAD_PRMT_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_PRMT_AMEND - column 6!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AMEND_GEOM - column 2!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AMEND_GEOM - column 3!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AUDIT - column 3!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AUDIT - column 4!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AUDIT - column 5!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AUDIT - column 6!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AUDIT - column 9!
# Table DBQ01.DBQ01.the.ROAD_SECTION_AUDIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_AUDIT - column 10!
# Table DBQ01.DBQ01.the.ROAD_SECTION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_GEOM - column 3!
# Table DBQ01.DBQ01.the.ROAD_SECTION_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.ROAD_SECTION_GEOM - column 4!
# Table DBQ01.DBQ01.the.SEISMIC_LINE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.SEISMIC_LINE - column 9!
# Table DBQ01.DBQ01.the.TENURE_TERM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TENURE_TERM - column 2!
# Table DBQ01.DBQ01.the.TENURE_TERM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TENURE_TERM - column 3!
# Table DBQ01.DBQ01.the.TENURE_TERM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TENURE_TERM - column 4!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AMEND_GEOM - column 4!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AMEND_GEOM - column 6!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AREA - column 1!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AREA - column 2!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AREA - column 3!
# Table DBQ01.DBQ01.the.TIMBER_LIC_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_AREA - column 4!
# Table DBQ01.DBQ01.the.TIMBER_LIC_ELIM_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_ELIM_AMEND_GEOM - column 4!
# Table DBQ01.DBQ01.the.TIMBER_LIC_ELIM_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_ELIM_AMEND_GEOM - column 5!
# Table DBQ01.DBQ01.the.TIMBER_LIC_ELIM_AMEND_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_ELIM_AMEND_GEOM - column 6!
# Table DBQ01.DBQ01.the.TIMBER_LIC_ELIM_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_ELIM_GEOM - column 3!
# Table DBQ01.DBQ01.the.TIMBER_LIC_ELIM_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_ELIM_GEOM - column 4!
# Table DBQ01.DBQ01.the.TIMBER_LIC_ELIM_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_ELIM_GEOM - column 5!
# Table DBQ01.DBQ01.the.TIMBER_LIC_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_GEOM - column 3!
# Table DBQ01.DBQ01.the.TIMBER_LIC_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_GEOM - column 4!
# Table DBQ01.DBQ01.the.TIMBER_LIC_GEOM exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_LIC_GEOM - column 5!
# Table DBQ01.DBQ01.the.TIMBER_MARK exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_MARK - column 21!
# Table DBQ01.DBQ01.the.TIMBER_TENURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_TENURE - column 3!
# Table DBQ01.DBQ01.the.TIMBER_TENURE exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TIMBER_TENURE - column 4!
# Table DBQ01.DBQ01.the.TL_BLOCK_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TL_BLOCK_AREA - column 1!
# Table DBQ01.DBQ01.the.TL_BLOCK_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TL_BLOCK_AREA - column 2!
# Table DBQ01.DBQ01.the.TL_BLOCK_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TL_BLOCK_AREA - column 3!
# Table DBQ01.DBQ01.the.TL_BLOCK_AREA exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TL_BLOCK_AREA - column 4!
# Table DBQ01.DBQ01.the.TL_BLOCK_AREA_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TL_BLOCK_AREA_AMEND - column 3!
# Table DBQ01.DBQ01.the.TMBR_MARK_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TMBR_MARK_AMEND - column 1!
# Table DBQ01.DBQ01.the.TMBR_MARK_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TMBR_MARK_AMEND - column 3!
# Table DBQ01.DBQ01.the.TMBR_MARK_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TMBR_MARK_AMEND - column 6!
# Table DBQ01.DBQ01.the.TMBR_MARK_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TMBR_MARK_AMEND - column 7!
# Table DBQ01.DBQ01.the.TMBR_MARK_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TMBR_MARK_AMEND - column 8!
# Table DBQ01.DBQ01.the.TMBR_MARK_AMEND exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.TMBR_MARK_AMEND - column 9!
# Table DBQ01.DBQ01.the.XMASTREE_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.XMASTREE_COMMIT - column 2!
# Table DBQ01.DBQ01.the.XMASTREE_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.XMASTREE_COMMIT - column 3!
# Table DBQ01.DBQ01.the.XMASTREE_COMMIT exists. Proceeding to add tag.
# Tag added successfully for DBQ01.DBQ01.the.XMASTREE_COMMIT - column 4!
